# %% [markdown]
# ## Analysis Section: The three observations made in this exhibit/challenge are:
#
# ### 1.  This will actually be your last step once you run code below
#
# ### 2.  You will insert this cell above the one below
#
# ### 3.  How to do markdown in Jupyter Notebook?  https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
mouse_metadata
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0       k403     Ramicane    Male          21          16
# 1       s185    Capomulin  Female           3          17
# 2       x401    Capomulin  Female          16          15
# 3       m601    Capomulin    Male          22          17
# 4       g791     Ramicane    Male          11          16
# ..       ...          ...     ...         ...         ...
# 244     z314     Stelasyn  Female          21          28
# 245     z435     Propriva  Female          12          26
# 246     z581    Infubinol  Female          24          25
# 247     z795     Naftisol  Female          13          29
# 248     z969     Naftisol    Male           9          30
#
# [249 rows x 5 columns]

# %%
#start cleaning data & break it down 
study_results = pd.read_csv(study_results_path)
study_results.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
#put data frames together 
bigdata_df = pd.merge(study_results, mouse_metadata, on=["Mouse ID"])
bigdata_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
# Checking the number of mice.
# counting unique values
Mice_count = len(pd.unique(bigdata_df['Mouse ID']))
  
Mice_count
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 


double_mouse = bigdata_df[bigdata_df.duplicated()]
print(double_mouse)
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 861     g989          0                45.0                 0     Propriva
#
#         Sex  Age_months  Weight (g)
# 861  Female          21          26

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

bigdata_df_fixed = bigdata_df[bigdata_df['Mouse ID'] != "g989"]
bigdata_df_fixed = pd.DataFrame(bigdata_df_fixed)
bigdata_df_fixed
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice in the clean DataFrame.
Mice_count_2 = len(pd.unique(bigdata_df_fixed['Mouse ID']))
  
Mice_count_2
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
#created a df to start breaking the data down with
starter_df = bigdata_df_fixed[['Drug Regimen', 'Tumor Volume (mm3)']]
starter_df.head()
# Out:
#   Drug Regimen  Tumor Volume (mm3)
# 0    Capomulin           45.000000
# 1    Capomulin           45.651331
# 2    Capomulin           43.270852
# 3    Capomulin           43.784893
# 4    Capomulin           42.731552

# %%
#calculated the mean 
avgvol_df  = starter_df.groupby("Drug Regimen").mean()
avgvol_df = pd.DataFrame(avgvol_df)

#renamed Columns
avgvol_df = avgvol_df.rename(columns = {'Tumor Volume (mm3)' : 'Mean Volume'})
avgvol_df.head(3)
# Out:
#               Mean Volume
# Drug Regimen
# Capomulin       40.675741
# Ceftamin        52.591172
# Infubinol       52.884795

# %%
#calculated the mean
medvol_df  = starter_df.groupby("Drug Regimen").median()
medvol_df = pd.DataFrame(medvol_df)
#renamed columns
medvol_df = medvol_df.rename(columns = {'Tumor Volume (mm3)' : 'Median Volume'})
medvol_df.head(3)
# Out:
#               Median Volume
# Drug Regimen
# Capomulin         41.557809
# Ceftamin          51.776157
# Infubinol         51.820584

# %%
#Calculated Variance & renamed Columns
variance_df = starter_df.groupby("Drug Regimen").var()
variance_df = pd.DataFrame(variance_df)

variance_df = variance_df.rename(columns = {'Tumor Volume (mm3)' : 'Variance'})
variance_df.head(3)
# Out:
#                Variance
# Drug Regimen
# Capomulin     24.947764
# Ceftamin      39.290177
# Infubinol     43.128684

# %%
#Calculated Standard Deviation & renamed Columns
standev_df = starter_df.groupby("Drug Regimen").std()
standev_df = pd.DataFrame(standev_df)

standev_df = standev_df.rename(columns = {'Tumor Volume (mm3)' : 'Std. Deviation'})
standev_df.head(3)
# Out:
#               Std. Deviation
# Drug Regimen
# Capomulin           4.994774
# Ceftamin            6.268188
# Infubinol           6.567243

# %%
#Calculated Standard Error & renamed Columns
error_df = starter_df.groupby("Drug Regimen").sem()
error_df = pd.DataFrame(error_df)
                        
error_df = error_df.rename(columns = {'Tumor Volume (mm3)' : 'Std. Error'})                      
error_df.head(3)
# Out:
#               Std. Error
# Drug Regimen
# Capomulin       0.329346
# Ceftamin        0.469821
# Infubinol       0.492236

# %%
#began merging DF's 
df_1 = pd.merge(avgvol_df, medvol_df, on="Drug Regimen")
df_1
# Out:
#               Mean Volume  Median Volume
# Drug Regimen
# Capomulin       40.675741      41.557809
# Ceftamin        52.591172      51.776157
# Infubinol       52.884795      51.820584
# Ketapril        55.235638      53.698743
# Naftisol        54.331565      52.509285
# Placebo         54.033581      52.288934
# Propriva        52.320930      50.446266
# Ramicane        40.216745      40.673236
# Stelasyn        54.233149      52.431737
# Zoniferol       53.236507      51.818479

# %%
#Continued merging Df's
df_2 = pd.merge(df_1, variance_df, on="Drug Regimen")
df_2
# Out:
#               Mean Volume  Median Volume   Variance
# Drug Regimen
# Capomulin       40.675741      41.557809  24.947764
# Ceftamin        52.591172      51.776157  39.290177
# Infubinol       52.884795      51.820584  43.128684
# Ketapril        55.235638      53.698743  68.553577
# Naftisol        54.331565      52.509285  66.173479
# Placebo         54.033581      52.288934  61.168083
# Propriva        52.320930      50.446266  43.852013
# Ramicane        40.216745      40.673236  23.486704
# Stelasyn        54.233149      52.431737  59.450562
# Zoniferol       53.236507      51.818479  48.533355

# %%
#Continued merging Df's
df_3 = pd.merge(df_2, standev_df, on="Drug Regimen")
df_3
# Out:
#               Mean Volume  Median Volume   Variance  Std. Deviation
# Drug Regimen
# Capomulin       40.675741      41.557809  24.947764        4.994774
# Ceftamin        52.591172      51.776157  39.290177        6.268188
# Infubinol       52.884795      51.820584  43.128684        6.567243
# Ketapril        55.235638      53.698743  68.553577        8.279709
# Naftisol        54.331565      52.509285  66.173479        8.134708
# Placebo         54.033581      52.288934  61.168083        7.821003
# Propriva        52.320930      50.446266  43.852013        6.622085
# Ramicane        40.216745      40.673236  23.486704        4.846308
# Stelasyn        54.233149      52.431737  59.450562        7.710419
# Zoniferol       53.236507      51.818479  48.533355        6.966589

# %%
#generate stats table summary 
df_plot = pd.merge(df_3, error_df, on="Drug Regimen")
df_plot
# Out:
#               Mean Volume  Median Volume   Variance  Std. Deviation  \
# Drug Regimen
# Capomulin       40.675741      41.557809  24.947764        4.994774
# Ceftamin        52.591172      51.776157  39.290177        6.268188
# Infubinol       52.884795      51.820584  43.128684        6.567243
# Ketapril        55.235638      53.698743  68.553577        8.279709
# Naftisol        54.331565      52.509285  66.173479        8.134708
# Placebo         54.033581      52.288934  61.168083        7.821003
# Propriva        52.320930      50.446266  43.852013        6.622085
# Ramicane        40.216745      40.673236  23.486704        4.846308
# Stelasyn        54.233149      52.431737  59.450562        7.710419
# Zoniferol       53.236507      51.818479  48.533355        6.966589
#
#               Std. Error
# Drug Regimen
# Capomulin       0.329346
# Ceftamin        0.469821
# Infubinol       0.492236
# Ketapril        0.603860
# Naftisol        0.596466
# Placebo         0.581331
# ...

# %%
#Aggregate summary
aggregate_df = starter_df.groupby("Drug Regimen").agg(["mean", "median", "var", "std", "sem"])
aggregate_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
#created starting DF 
bar_starter_df = bigdata_df_fixed[['Drug Regimen', 'Timepoint']]
bar_starter_df.head()
# Out:
#   Drug Regimen  Timepoint
# 0    Capomulin          0
# 1    Capomulin          5
# 2    Capomulin         10
# 3    Capomulin         15
# 4    Capomulin         20

# %%
#Group the data by Drug Regimen
mice = bar_starter_df.groupby("Drug Regimen").count()
mice
# Out:
#               Timepoint
# Drug Regimen
# Capomulin           230
# Ceftamin            178
# Infubinol           178
# Ketapril            188
# Naftisol            186
# Placebo             181
# Propriva            148
# Ramicane            228
# Stelasyn            181
# Zoniferol           182

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
mice.plot(kind="bar", figsize = (6,4), ylim = (0,250), legend = False,
                        title = 'Number of Time Points For All Mice', width = 0.5)

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
x_axis = mice.index
y_axis = mice["Timepoint"].tolist()
plt.bar(x_axis, y_axis)
plt.xticks(rotation = 'vertical')
plt.xlabel("Drug Regimen")
plt.title("Number of Time Points For All mice")
plt.show()

# %%
#Get number of male mice
gender_df = bigdata_df_fixed[["Mouse ID", "Sex"]]


male_df = gender_df.loc[gender_df["Sex"] == "Male",:]
male_count = len(male_df)
male_count
# Out:
# 958

# %%
#get number of female mice
female_df = gender_df.loc[gender_df["Sex"] == "Female",:]
female_count = len(female_df)
female_count
# Out:
# 922

# %%
#create summary 
totals_df = [{"Male": "958", 
              "Female": "922", 
              "Total": "1880"}]
totals_MF_df = pd.DataFrame(totals_df)
totals_MF_df
# Out:
#   Male Female Total
# 0  958    922  1880

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-09c68f70f954> in <module>
#       1 # Generate a pie plot showing the distribution of female versus male mice using Pandas
# ----> 2 pandas_plot = totals_MF_df.plot.pie(subplots=True, autopct="%1.1f%%", title ="Mice Tested by Gender", figsize=(11, 6))
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in pie(self, **kwargs)
#    1416         ):
#    1417             raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1418         return self(kind="pie", **kwargs)
#    1419
#    1420     def scatter(self, x, y, s=None, c=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
# ...

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
Totals = [958,922]

my_labels = 'Male','Female'
plt.pie(Totals,labels=my_labels,autopct='%1.1f%%')
plt.title('Mouse Totals by Sex')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes

    
    # add subset 

    
    # Determine outliers using upper and lower bounds
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
